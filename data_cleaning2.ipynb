# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
import numpy as np

# %%
FILE_PATH = "csv/copy.csv"

# %% [markdown]
# ## Date :- 2026-04-20

# %%
df = pd.read_csv(FILE_PATH)

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  employed  default
# 0   47  151735           616               1         1        0
# 1   40   72912           781               1         1        0
# 2   49  152455           568               2         0        0
# 3   60  120771           654               1         1        1
# 4   39   86572           767               1         1        0

# %%
mask = (df["existing_loans"]<1, "default")
df.loc[mask]
# Out:
# 35      0
# 43      0
# 46      0
# 63      0
# 67      0
#        ..
# 4957    0
# 4959    0
# 4966    0
# 4973    0
# 4998    0
# Name: default, Length: 657, dtype: int64

# %%
df.loc[
    (df["existing_loans"]==0) &
    (df["default"]>0)
]
# Out:
# Empty DataFrame
# Columns: [age, income, credit_score, existing_loans, employed, default]
# Index: []
