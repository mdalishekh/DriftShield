# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
import numpy as np

# %%
FILE_PATH = "csv/copy.csv"

# %% [markdown]
# ## Date :- 2026-04-20

# %%
df = pd.read_csv(FILE_PATH)

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  employed  default  loan_amount  \
# 0   47  151735           616               1         1        0            0
# 1   40   72912           781               1         1        0            0
# 2   49  152455           568               2         0        0            0
# 3   60  120771           654               1         1        1            0
# 4   39   86572           767               1         1        0            0
#
#    loan_tenure_months
# 0                  36
# 1                  36
# 2                  36
# 3                  36
# 4                  36

# %%
mask = (df["existing_loans"]<1, "default")
df.loc[mask]
# Out:
# 35      0
# 43      0
# 46      0
# 63      0
# 67      0
#        ..
# 4957    0
# 4959    0
# 4966    0
# 4973    0
# 4998    0
# Name: default, Length: 657, dtype: int64

# %%
df.loc[
    (df["existing_loans"]==0) &
    (df["default"]>0)
]
# Out:
# Empty DataFrame
# Columns: [age, income, credit_score, existing_loans, employed, default, loan_amount, loan_tenure_months]
# Index: []

# %%
df["loan_amount"] = 0

# %%
df.rename(columns={"loan":"loan_amount"}, inplace=True)

# %%
tier1 = (df["employed"]==0) & \
(df["credit_score"]<550) & \
(df["age"]<30)

# %%
df.loc[tier1]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 991    25    4716           513               0         0        0
# 1573   25    3070           539               1         0        0
# 2154   26    4500           546               0         0        0
# 2970   25    3973           519               1         0        1
# 4163   25    3149           536               0         0        0
# 4747   28    4928           513               0         0        0
#
#       loan_amount  loan_tenure_months
# 991             0                  36
# 1573            0                  36
# 2154            0                  36
# 2970            0                  36
# 4163            0                  36
# 4747            0                  36

# %%
df["loan_tenure_months"] = 36

# %%
loan_multiplier = df.loc[tier1, "income"]*2

# %%
l = loan_multiplier*np.round(np.random.uniform(0.95, 1.1, size=df[tier1].shape[0]))

# %%
df.loc[tier1, "loan_amount"] = l

# %%
df.loc[tier1]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 991    25    4716           513               0         0        0
# 1573   25    3070           539               1         0        0
# 2154   26    4500           546               0         0        0
# 2970   25    3973           519               1         0        1
# 4163   25    3149           536               0         0        0
# 4747   28    4928           513               0         0        0
#
#       loan_amount  loan_tenure_months
# 991          9432                  36
# 1573         6140                  36
# 2154         9000                  36
# 2970         7946                  36
# 4163         6298                  36
# 4747         9856                  36

# %% [markdown]
# ## TIER 2

# %%
tier2 = (df["employed"]==0) & \
    (df["credit_score"].between(551, 750)) & \
    (df["age"]>=50) & \
    (df["existing_loans"].between(0, 2))

# %%
df.loc[
    (df["employed"]==0) &
    (df["credit_score"].between(551, 750)) &
    (df["age"]>=50) & 
    (df["existing_loans"].between(0, 2))
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 67     54   15926           653               0         0        0
# 75     51   17187           662               0         0        0
# 106    64    8737           738               1         0        0
# 118    55    8336           680               2         0        1
# 135    60   14495           708               0         0        0
# ...   ...     ...           ...             ...       ...      ...
# 4857   53   15705           707               2         0        0
# 4905   53   15661           685               0         0        0
# 4923   58   11475           656               1         0        0
# 4970   60   16573           696               1         0        0
# 4976   58   15020           695               2         0        1
#
#       loan_amount  loan_tenure_months
# 67         111482                  36
# 75         120309                  36
# 106         61159                  36
# ...

# %%
df.loc[tier2].shape
# Out:
# (82, 8)

# %%
# # High previous earners → high pension
# df.loc[(tier2) & (df['income'] > 100000), 'income'] = np.random.randint(15000, 20000, size=46)

# df.loc[(tier2) & (df['income'].between(50000, 100000)), 'income'] = np.random.randint(8000, 15000, size=35)

# df.loc[(tier2) & (df['income'] < 50000), 'income'] = 6000

# %%
df.loc[(tier2) & (df['income'] > 100000)]
# Out:
# Empty DataFrame
# Columns: [age, income, credit_score, existing_loans, employed, default, loan_amount, loan_tenure_months]
# Index: []

# %%
df.loc[(tier2) & (df['income'].between(50000, 100000)), "income"] = np.random.randint(8000, 15000, size=35)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.loc[(tier2) & (df['income'].between(50000, 100000)), "income"] = np.random.randint(8000, 15000, size=35)
#
# File ~\anaconda3\envs\data-science\Lib\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\envs\data-science\Lib\site-packages\pandas\core\indexing.py:1942, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1939 # align and set the values
#    1940 if take_split_path:
#    1941     # We have to operate column-wise
# -> 1942     self._setitem_with_indexer_split_path(indexer, value, name)
#    1943 else:
# ...

# %%
df.loc[(tier2) & (df['income'] < 50000), "income"] = 6000

# %%
df.loc[(tier2) & (df['income'].between(8000, 15000)) ]

# %%
df.loc[(tier2) & (df['income'] > 100000), 'income'] = np.random.randint(15000, 20000, size=46)

# %%
df.loc[(tier2) & (df['income'] > 15000)]

# %%
df.to_csv(FILE_PATH, index=False)

# %%
df = pd.read_csv(FILE_PATH)

# %%
df.loc[tier2, 'loan_amount'] = df.loc[tier2, 'income'] * 7 * np.round(np.random.uniform(0.9, 1.1, size=tier2.sum()))

# %%
df.loc[tier2]

# %%
df.to_csv(FILE_PATH, index=False)

# %% [markdown]
# ## Date:- 2026-04-21

# %%
import pandas as pd
import numpy as np

# %%
FILE_PATH = "csv/copy.csv"

# %%
df = pd.read_csv(FILE_PATH)

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  employed  default  loan_amount  \
# 0   47  151735           616               1         1        0            0
# 1   40   72912           781               1         1        0            0
# 2   49  152455           568               2         0        0            0
# 3   60  120771           654               1         1        1            0
# 4   39   86572           767               1         1        0            0
#
#    loan_tenure_months
# 0                  36
# 1                  36
# 2                  36
# 3                  36
# 4                  36

# %%
df.loc[tier2]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 67     54   15926           653               0         0        0
# 75     51   17187           662               0         0        0
# 106    64    8737           738               1         0        0
# 118    55    8336           680               2         0        1
# 135    60   14495           708               0         0        0
# ...   ...     ...           ...             ...       ...      ...
# 4857   53   15705           707               2         0        0
# 4905   53   15661           685               0         0        0
# 4923   58   11475           656               1         0        0
# 4970   60   16573           696               1         0        0
# 4976   58   15020           695               2         0        1
#
#       loan_amount  loan_tenure_months
# 67         111482                  36
# 75         120309                  36
# 106         61159                  36
# ...

# %%
df.head(2)
# Out:
#    age  income  credit_score  existing_loans  employed  default  loan_amount  \
# 0   47  151735           616               1         1        0            0
# 1   40   72912           781               1         1        0            0
#
#    loan_tenure_months
# 0                  36
# 1                  36

# %% [markdown]
# ## Tier 3

# %%
tier3 = (df["employed"]==1) & \
(df["credit_score"]<550) & \
(df["age"]<35) & \
(df["income"]<=50000) & \
(df["existing_loans"].between(0, 2))

# %%
df.loc[tier3]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 382    25   20597           493               1         1        0
# 1561   33   49116           375               1         1        0
# 1763   25   37158           539               0         1        0
# 2344   25   46616           548               0         1        0
# 3454   25   24791           481               2         1        1
# 3861   32   46206           537               2         1        1
# 4219   25   26060           540               2         1        0
# 4478   25   24131           548               2         1        0
# 4498   25   25024           540               1         1        0
#
#       loan_amount  loan_tenure_months
# 382             0                  36
# 1561            0                  36
# 1763            0                  36
# 2344            0                  36
# 3454            0                  36
# 3861            0                  36
# ...

# %%
df[tier3].shape
# Out:
# (9, 8)

# %%
# Sab ko 3x multiplier + randomness
df.loc[tier3, 'loan_amount'] = df.loc[tier3, 'income'] * 3 * \
                                np.round(np.random.uniform(0.9, 1.1, size=df[tier3].shape[0]))

# %%
df.loc[tier3]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 382    25   20597           493               1         1        0
# 1561   33   49116           375               1         1        0
# 1763   25   37158           539               0         1        0
# 2344   25   46616           548               0         1        0
# 3454   25   24791           481               2         1        1
# 3861   32   46206           537               2         1        1
# 4219   25   26060           540               2         1        0
# 4478   25   24131           548               2         1        0
# 4498   25   25024           540               1         1        0
#
#       loan_amount  loan_tenure_months
# 382       61791.0                  36
# 1561     147348.0                  36
# 1763     111474.0                  36
# 2344     139848.0                  36
# 3454      74373.0                  36
# 3861     138618.0                  36
# ...

# %%
d = df.loc[
    (df["loan_amount"]==0)
]

# %%
d.shape
# Out:
# (4903, 8)

# %% [markdown]
# ## Tier 4

# %%
tier4 = (df['employed'] == 1) & \
        (df['credit_score'] < 550) & \
        (df['age'] >= 50) & \
        (df['income'] >= 100000) & \
        (df['existing_loans'].between(0, 3))

# %%
df.loc[tier4, 'loan_amount'] = df.loc[tier4, 'income'] * 5 * \
                                np.round(np.random.uniform(0.9, 1.1, size=df[tier4].shape[0]))

# %%
df.loc[tier4, 'loan_amount'] = df.loc[tier4, 'loan_amount'].astype(int)

# %%
df[tier4]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 202    54  101514           484               2         1        0
# 500    53  124327           531               1         1        0
# 707    63  152150           549               1         1        0
# 928    60  142153           541               3         1        0
# 1010   57  102784           530               0         1        0
# 1161   69  158341           467               1         1        0
# 1296   53  114860           545               1         1        1
# 1507   53  105184           399               3         1        1
# 1615   70  197620           513               3         1        1
# 1627   57  126038           520               1         1        0
# 1854   54  157472           520               1         1        0
# 2235   50  116333           543               3         1        0
# 2249   53  108241           537               0         1        0
# ...

# %% [markdown]
# ## Tier 5

# %%
tier5 = (df['employed'] == 1) & \
        (df['credit_score'].between(550, 750)) & \
        (df['age'].between(35, 50)) & \
        (df['income'].between(60000, 120000)) & \
        (df['existing_loans'].between(1, 3))

# %%
df[tier5].shape
# Out:
# (656, 8)

# %%
df.loc[tier5, 'loan_amount'] = df.loc[tier5, 'income'] * 6 * \
                                np.round(np.random.uniform(0.9, 1.1, size=df[tier5].shape[0]))

# %%
df.loc[tier5, 'loan_amount'] = df.loc[tier5, 'loan_amount'].astype(int)

# %%
df[tier5]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 8      36   65670           674               1         1        0
# 10     36   66486           609               2         1        0
# 12     44   84268           681               2         1        0
# 21     39   86326           702               1         1        0
# 27     46   77197           749               2         1        1
# ...   ...     ...           ...             ...       ...      ...
# 4984   48  102284           555               1         1        0
# 4986   39   74420           697               1         1        0
# 4991   50   81283           651               1         1        0
# 4992   40  116169           693               1         1        1
# 4995   41   75968           745               2         1        0
#
#       loan_amount  loan_tenure_months
# 8        394020.0                  36
# 10       398916.0                  36
# 12       505608.0                  36
# ...

# %% [markdown]
# ## Tier 6

# %%
tier6 = (df['employed'] == 1) & \
        (df['credit_score'].between(550, 700)) & \
        (df['age'].between(30, 45)) & \
        (df['income'].between(40000, 70000)) & \
        (df['existing_loans'].between(1, 2)) & \
        (df["loan_amount"]==0)

# %%
df[tier6]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5      39   49276           695               1         1        0
# 36     44   58536           624               2         1        0
# 57     38   58615           674               2         1        0
# 58     45   57903           597               2         1        0
# 60     36   45629           643               2         1        1
# ...   ...     ...           ...             ...       ...      ...
# 4707   36   43587           643               2         1        1
# 4753   37   58190           692               2         1        0
# 4867   41   50824           635               1         1        1
# 4925   35   47131           677               2         1        0
# 4934   36   49726           601               1         1        0
#
#       loan_amount  loan_tenure_months
# 5             0.0                  36
# 36            0.0                  36
# 57            0.0                  36
# ...

# %%
df[tier6].shape
# Out:
# (109, 8)

# %%
df.loc[(tier6) & (df["loan_amount"]==0)]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5      39   49276           695               1         1        0
# 36     44   58536           624               2         1        0
# 57     38   58615           674               2         1        0
# 58     45   57903           597               2         1        0
# 60     36   45629           643               2         1        1
# ...   ...     ...           ...             ...       ...      ...
# 4707   36   43587           643               2         1        1
# 4753   37   58190           692               2         1        0
# 4867   41   50824           635               1         1        1
# 4925   35   47131           677               2         1        0
# 4934   36   49726           601               1         1        0
#
#       loan_amount  loan_tenure_months
# 5             0.0                  36
# 36            0.0                  36
# 57            0.0                  36
# ...

# %%
df.loc[tier6,'loan_amount'] = df.loc[tier6, 'income'] * 4 * \
                                np.round(np.random.uniform(0.9, 1.1, size=df[tier6].shape[0]))

# %%
df.loc[tier6, 'loan_amount'] = df.loc[tier6, 'loan_amount'].astype(int)

# %%
df[tier6].shape
# Out:
# (109, 8)

# %%
df[df["loan_amount"]==0].shape
# Out:
# (4007, 8)

# %% [markdown]
# ## Tier 7

# %%
tier7 = (df['employed'] == 1) & \
        (df['credit_score'] >= 750) & \
        (df['age'] >= 50) & \
        (df['income'] >= 120000) & \
        (df['loan_amount'] == 0)

# %%
df[tier7]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 6      60  137459           790               1         1        0
# 122    58  133286           770               5         1        0
# 141    57  128478           807               3         1        0
# 167    64  131239           770               3         1        1
# 248    63  198484           784               2         1        0
# ...   ...     ...           ...             ...       ...      ...
# 4838   58  197470           778               2         1        0
# 4856   52  151311           753               0         1        0
# 4937   56  144512           776               2         1        0
# 4957   54  141707           771               0         1        0
# 4997   70  153435           788               2         1        0
#
#       loan_amount  loan_tenure_months
# 6             0.0                  36
# 122           0.0                  36
# 141           0.0                  36
# ...

# %%
df.loc[tier7, 'loan_amount'] = df.loc[tier7, 'income'] * 8 * \
                                np.round(np.random.uniform(0.9, 1.1, size=df[tier7].shape[0]))

# %%
df.loc[tier7, 'loan_amount'] = df.loc[tier7, 'loan_amount'].astype(int)

# %%
df[tier7]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 6      60  137459           790               1         1        0
# 122    58  133286           770               5         1        0
# 141    57  128478           807               3         1        0
# 167    64  131239           770               3         1        1
# 248    63  198484           784               2         1        0
# ...   ...     ...           ...             ...       ...      ...
# 4838   58  197470           778               2         1        0
# 4856   52  151311           753               0         1        0
# 4937   56  144512           776               2         1        0
# 4957   54  141707           771               0         1        0
# 4997   70  153435           788               2         1        0
#
#       loan_amount  loan_tenure_months
# 6       1099672.0                  36
# 122     1066288.0                  36
# 141     1027824.0                  36
# ...

# %% [markdown]
# ## Tier 8

# %%
df[df["loan_amount"]==0].shape
# Out:
# (3882, 8)

# %%
unassigned = df[df['loan_amount'] == 0]
print(unassigned[['age', 'income', 'credit_score', 'employed', 'existing_loans']].describe())

# Pattern dekh
print(unassigned['employed'].value_counts())
print(unassigned['credit_score'].describe())
# Out:
#                age         income  credit_score     employed  existing_loans
# count  3882.000000    3882.000000   3882.000000  3882.000000     3882.000000
# mean     41.299845   88845.377640    704.206079     0.867079        2.046368
# std      11.577851   40334.918053     82.511734     0.339533        1.457608
# min      25.000000   20246.000000    427.000000     0.000000        0.000000
# 25%      31.000000   55732.500000    646.000000     1.000000        1.000000
# 50%      41.000000   81680.000000    706.000000     1.000000        2.000000
# 75%      50.000000  119525.500000    762.000000     1.000000        3.000000
# max      70.000000  199869.000000    900.000000     1.000000        5.000000
# employed
# 1    3366
# 0     516
# Name: count, dtype: int64
# count    3882.000000
# mean      704.206079
# std        82.511734
# min       427.000000
# 25%       646.000000
# 50%       706.000000
# 75%       762.000000
# max       900.000000
# Name: credit_score, dtype: float64

# %%
df.to_csv(FILE_PATH, index=False)

# %%
df[tier7]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 6      60  137459           790               1         1        0
# 122    58  133286           770               5         1        0
# 141    57  128478           807               3         1        0
# 167    64  131239           770               3         1        1
# 248    63  198484           784               2         1        0
# ...   ...     ...           ...             ...       ...      ...
# 4838   58  197470           778               2         1        0
# 4856   52  151311           753               0         1        0
# 4937   56  144512           776               2         1        0
# 4957   54  141707           771               0         1        0
# 4997   70  153435           788               2         1        0
#
#       loan_amount  loan_tenure_months
# 6       1099672.0                  36
# 122     1066288.0                  36
# 141     1027824.0                  36
# ...
