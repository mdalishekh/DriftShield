# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
import numpy as np
FILE = "csv-2/copy.csv"
df = pd.read_csv(FILE)

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  employed  default  loan_amount  \
# 0   47  105384           616               1         1        0       526920
# 1   40   69517           781               1         1        0       417102
# 2   49   28572           568               2         0        0        83408
# 3   60   71067           654               1         1        1       284268
# 4   39   68930           767               1         1        0       413580
#
#    loan_tenure_months
# 0                  36
# 1                  36
# 2                  36
# 3                  36
# 4                  36

# %% [markdown]
# ## Assigning Loans to EMPLOYED people

# %%
## Worst Cibil 

worst_emp = (df['employed'] == 1) & (df['credit_score'] < 400)

# %%
worst_emp = (df['employed'] == 1) & (df['credit_score'] < 400)


df.loc[(worst_emp) & (df['age'].between(30, 40)), 'loan_amount'] = \
    df.loc[(worst_emp) & (df['age'].between(30, 40)), 'income'] * np.random.randint(4, 6, size=df[(worst_emp) & (df['age'].between(30, 40))].shape[0])

df.loc[(worst_emp) & (df['age'].between(41, 55)), 'loan_amount'] = \
    np.maximum(df.loc[(worst_emp) & (df['age'].between(41, 55)), 'income'] * np.random.randint(4, 6, size=df[(worst_emp) & (df['age'].between(41, 55))].shape[0]), 500000)



df.loc[worst_emp, 'loan_amount'] = df.loc[worst_emp, 'loan_amount'].astype(int)

print(f"Employed worst credit loans assigned! {worst_emp.sum()} rows now")
# Out:
# Employed worst credit loans assigned! 269 rows now

# %%
df[worst_emp]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 1507   53  109011           399               3         1        1
# 1561   33   53733           375               1         1        0
# 5263   70       0           361               2         1        0
# 5264   68       0           341               0         1        0
# 5265   43       0           332               2         1        0
# ...   ...     ...           ...             ...       ...      ...
# 5527   58       0           314               0         1        0
# 5528   66       0           392               2         1        0
# 5530   50       0           399               0         1        0
# 5531   33       0           341               0         1        0
# 5532   38       0           333               2         1        0
#
#       loan_amount  loan_tenure_months
# 1507       545055                  36
# 1561       214932                  36
# 5263            0                  36
# ...

# %%
## POOR cibil 
poor_emp = (df['employed'] == 1) & (df['credit_score'].between(401, 550))

# %%
df.loc[(poor_emp) & (df['age'].between(25, 29)), 'loan_amount'] = \
    df.loc[(poor_emp) & (df['age'].between(25, 29)), 'income'] * np.random.randint(5, 7, size=df[(poor_emp) & (df['age'].between(25, 29))].shape[0])

df.loc[(poor_emp) & (df['age'].between(30, 40)), 'loan_amount'] = \
    df.loc[(poor_emp) & (df['age'].between(30, 40)), 'income'] * np.random.randint(5, 7, size=df[(poor_emp) & (df['age'].between(30, 40))].shape[0])

df.loc[(poor_emp) & (df['age'].between(41, 55)), 'loan_amount'] = \
    df.loc[(poor_emp) & (df['age'].between(41, 55)), 'income'] * np.random.randint(5, 7, size=df[(poor_emp) & (df['age'].between(41, 55))].shape[0])

df.loc[(poor_emp) & (df['age'].between(56, 59)), 'loan_amount'] = \
    df.loc[(poor_emp) & (df['age'].between(56, 59)), 'income'] * np.random.randint(5, 7, size=df[(poor_emp) & (df['age'].between(56, 59))].shape[0])

df.loc[(poor_emp) & (df['age'] >= 60), 'loan_amount'] = \
    df.loc[(poor_emp) & (df['age'] >= 60), 'income'] * np.random.randint(3, 5, size=df[(poor_emp) & (df['age'] >= 60)].shape[0])

df.loc[poor_emp, 'loan_amount'] = df.loc[poor_emp, 'loan_amount'].astype(int)

print(f"Employed poor credit loans assigned! {poor_emp.sum()} rows")
# Out:
# Employed poor credit loans assigned! 141 rows

# %%
df[poor_emp]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 7      51  117736           537               4         1        0
# 54     54  151874           510               5         1        1
# 89     48  118310           543               0         1        0
# 202    54  104257           484               2         1        0
# 226    42   67869           500               1         1        0
# ...   ...     ...           ...             ...       ...      ...
# 4722   42   65760           509               0         1        0
# 4774   25   30600           517               3         1        0
# 4948   37   79987           486               3         1        0
# 4953   53  152259           544               1         1        0
# 4960   38   65380           516               1         1        0
#
#       loan_amount  loan_tenure_months
# 7          588680                  36
# 54         759370                  36
# 89         591550                  36
# ...

# %%
## GOOD cibil 
good_emp = (df['employed'] == 1) & (df['credit_score'].between(551, 699))

# %%
df.loc[(good_emp) & (df['age'].between(25, 29)), 'loan_amount'] = \
    df.loc[(good_emp) & (df['age'].between(25, 29)), 'income'] * np.random.randint(5, 8, size=df[(good_emp) & (df['age'].between(25, 29))].shape[0])

df.loc[(good_emp) & (df['age'].between(30, 40)), 'loan_amount'] = \
    df.loc[(good_emp) & (df['age'].between(30, 40)), 'income'] * np.random.randint(5, 8, size=df[(good_emp) & (df['age'].between(30, 40))].shape[0])

df.loc[(good_emp) & (df['age'].between(41, 55)), 'loan_amount'] = \
    df.loc[(good_emp) & (df['age'].between(41, 55)), 'income'] * np.random.randint(5, 8, size=df[(good_emp) & (df['age'].between(41, 55))].shape[0])

df.loc[(good_emp) & (df['age'].between(56, 59)), 'loan_amount'] = \
    df.loc[(good_emp) & (df['age'].between(56, 59)), 'income'] * np.random.randint(5, 8, size=df[(good_emp) & (df['age'].between(56, 59))].shape[0])

df.loc[(good_emp) & (df['age'] >= 60), 'loan_amount'] = \
    df.loc[(good_emp) & (df['age'] >= 60), 'income'] * np.random.randint(4, 6, size=df[(good_emp) & (df['age'] >= 60)].shape[0])

df.loc[good_emp, 'loan_amount'] = df.loc[good_emp, 'loan_amount'].astype(int)

print(f"Employed good credit loans assigned! {good_emp.sum()} rows")
# Out:
# Employed good credit loans assigned! 2023 rows

# %%
df[good_emp]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 0      47  105384           616               1         1        0
# 3      60   71067           654               1         1        1
# 5      39   67947           695               1         1        0
# 8      36   68281           674               1         1        0
# 10     36   76048           609               2         1        0
# ...   ...     ...           ...             ...       ...      ...
# 4990   25   30843           667               2         1        0
# 4991   50  152453           651               1         1        0
# 4992   40   84042           693               1         1        1
# 4998   51  166975           638               0         1        0
# 4999   31   48188           674               1         1        0
#
#       loan_amount  loan_tenure_months
# 0          632304                  36
# 3          284268                  36
# 5          475629                  36
# ...

# %%
## BEST cibil 
best_emp = (df['employed'] == 1) & (df['credit_score'] >= 700)

# %%
df.loc[(best_emp) & (df['age'].between(25, 29)), 'loan_amount'] = \
    df.loc[(best_emp) & (df['age'].between(25, 29)), 'income'] * np.random.randint(6, 9, size=df[(best_emp) & (df['age'].between(25, 29))].shape[0])

df.loc[(best_emp) & (df['age'].between(30, 40)), 'loan_amount'] = \
    df.loc[(best_emp) & (df['age'].between(30, 40)), 'income'] * np.random.randint(6, 9, size=df[(best_emp) & (df['age'].between(30, 40))].shape[0])

df.loc[(best_emp) & (df['age'].between(41, 55)), 'loan_amount'] = \
    df.loc[(best_emp) & (df['age'].between(41, 55)), 'income'] * np.random.randint(6, 9, size=df[(best_emp) & (df['age'].between(41, 55))].shape[0])

df.loc[(best_emp) & (df['age'].between(56, 59)), 'loan_amount'] = \
    df.loc[(best_emp) & (df['age'].between(56, 59)), 'income'] * np.random.randint(6, 9, size=df[(best_emp) & (df['age'].between(56, 59))].shape[0])

df.loc[(best_emp) & (df['age'] >= 60), 'loan_amount'] = \
    df.loc[(best_emp) & (df['age'] >= 60), 'income'] * np.random.randint(5, 7, size=df[(best_emp) & (df['age'] >= 60)].shape[0])

df.loc[best_emp, 'loan_amount'] = df.loc[best_emp, 'loan_amount'].astype(int)

print(f"Employed best credit loans assigned! {best_emp.sum()} rows")
# Out:
# Employed best credit loans assigned! 2116 rows

# %%
df[best_emp]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 1      40   69517           781               1         1        0
# 4      39   68930           767               1         1        0
# 6      60   73017           790               1         1        0
# 9      48  149422           806               2         1        0
# 11     36   66951           782               1         1        0
# ...   ...     ...           ...             ...       ...      ...
# 4985   61   73889           735               2         1        0
# 4994   34   50808           839               1         1        0
# 4995   41   69736           745               2         1        0
# 4996   50  103089           768               3         1        0
# 4997   70   89423           788               2         1        0
#
#       loan_amount  loan_tenure_months
# 1          417102                  36
# 4          482510                  36
# 6          438102                  36
# ...

# %%
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 0      47  105384           616               1         1        0
# 1      40   69517           781               1         1        0
# 2      49   28572           568               2         0        0
# 3      60   71067           654               1         1        1
# 4      39   68930           767               1         1        0
# ...   ...     ...           ...             ...       ...      ...
# 4995   41   69736           745               2         1        0
# 4996   50  103089           768               3         1        0
# 4997   70   89423           788               2         1        0
# 4998   51  166975           638               0         1        0
# 4999   31   48188           674               1         1        0
#
#       loan_amount  loan_tenure_months
# 0          526920                  36
# 1          417102                  36
# 2           83408                  36
# ...

# %%
# Safe point

df.to_csv(FILE, index=False)

# %%
import pandas as pd
df = pd.read_csv(FILE)
df.head()
# Out:
#    age  income  credit_score  existing_loans  employed  default  loan_amount  \
# 0   47  105384           616               1         1        0       526920
# 1   40   69517           781               1         1        0       417102
# 2   49   28572           568               2         0        0        83408
# 3   60   71067           654               1         1        1       284268
# 4   39   68930           767               1         1        0       413580
#
#    loan_tenure_months
# 0                  36
# 1                  36
# 2                  36
# 3                  36
# 4                  36

# %%
df.loc[
    (df["loan_amount"]>0)
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 0      47  105384           616               1         1        0
# 1      40   69517           781               1         1        0
# 2      49   28572           568               2         0        0
# 3      60   71067           654               1         1        1
# 4      39   68930           767               1         1        0
# ...   ...     ...           ...             ...       ...      ...
# 5516   41       0           390               3         1        0
# 5519   44       0           305               1         1        0
# 5521   42       0           387               2         1        0
# 5524   44       0           359               3         1        0
# 5530   50       0           399               0         1        0
#
#       loan_amount  loan_tenure_months
# 0          632304                  36
# 1          417102                  36
# 2           83408                  36
# ...

# %% [markdown]
# ### Adding new rows for unemployed persons with worst credit score

# %%
import numpy as np

# Create 213 rows
new_rows_unemp = 263

new_data_unemp = {
    'age': np.random.randint(25, 71, size=new_rows_unemp),
    'income': 0,
    'credit_score': np.random.randint(300, 401, size=new_rows_unemp),
    'existing_loans': np.random.randint(0, 4, size=new_rows_unemp),
    'employed': 0,
    'default': 0,
    'loan_amount': 0,
    'loan_tenure_months': 36
}

new_df_unemp = pd.DataFrame(new_data_unemp)

# Append to main df
df = pd.concat([df, new_df_unemp], ignore_index=True)

print(f"Added {new_rows_unemp} unemployed worst credit rows!")
print(f"Total rows now: {df.shape[0]}")
# Out:
# Added 263 unemployed worst credit rows!
# Total rows now: 5796

# %%
df.loc[
    (df["loan_amount"]==0)
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5000   32       0           363               3         0        0
# 5001   70       0           334               0         0        0
# 5002   53       0           400               3         0        0
# 5003   26       0           342               3         0        0
# 5004   52       0           345               3         0        0
# ...   ...     ...           ...             ...       ...      ...
# 5791   36       0           353               1         0        0
# 5792   47       0           304               0         0        0
# 5793   68       0           351               1         0        0
# 5794   68       0           368               2         0        0
# 5795   60       0           397               2         0        0
#
#       loan_amount  loan_tenure_months
# 5000            0                  36
# 5001            0                  36
# 5002            0                  36
# ...

# %%
# Create 190 rows
new_rows_emp = 270

new_data_emp = {
    'age': np.random.randint(25, 71, size=new_rows_emp),
    'income': 0,
    'credit_score': np.random.randint(300, 401, size=new_rows_emp),
    'existing_loans': np.random.randint(0, 4, size=new_rows_emp),
    'employed': 1,
    'default': 0,
    'loan_amount': 0,
    'loan_tenure_months': 36
}

new_df_emp = pd.DataFrame(new_data_emp)

# Append to main df
df = pd.concat([df, new_df_emp], ignore_index=True)

print(f"Added {new_rows_emp} employed worst credit rows!")
print(f"Total rows now: {df.shape[0]}")
# Out:
# Added 270 employed worst credit rows!
# Total rows now: 5533

# %%
df.shape
# Out:
# (5796, 8)

# %%
df.loc[
    (df["employed"]==1) &
    (df["loan_amount"]==0)
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5263   70       0           361               2         1        0
# 5264   68       0           341               0         1        0
# 5266   37       0           325               0         1        0
# 5269   60       0           340               1         1        0
# 5271   34       0           356               3         1        0
# ...   ...     ...           ...             ...       ...      ...
# 5527   58       0           314               0         1        0
# 5528   66       0           392               2         1        0
# 5529   44       0           400               2         1        0
# 5531   33       0           341               0         1        0
# 5532   38       0           333               2         1        0
#
#       loan_amount  loan_tenure_months
# 5263            0                  36
# 5264            0                  36
# 5266            0                  36
# ...

# %%
df.loc[
    (df["employed"]==0) &
    (df["loan_amount"]==0)
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5000   32       0           363               3         0        0
# 5001   70       0           334               0         0        0
# 5002   53       0           400               3         0        0
# 5003   26       0           342               3         0        0
# 5004   52       0           345               3         0        0
# ...   ...     ...           ...             ...       ...      ...
# 5791   36       0           353               1         0        0
# 5792   47       0           304               0         0        0
# 5793   68       0           351               1         0        0
# 5794   68       0           368               2         0        0
# 5795   60       0           397               2         0        0
#
#       loan_amount  loan_tenure_months
# 5000            0                  36
# 5001            0                  36
# 5002            0                  36
# ...

# %%
# Safe point 

df.to_csv(FILE, index=False)

# %%
new_unemp = (df['employed'] == 0) & (df['income'] == 0)

# %%
df[new_unemp]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5000   32       0           363               3         0        0
# 5001   70       0           334               0         0        0
# 5002   53       0           400               3         0        0
# 5003   26       0           342               3         0        0
# 5004   52       0           345               3         0        0
# ...   ...     ...           ...             ...       ...      ...
# 5791   36       0           353               1         0        0
# 5792   47       0           304               0         0        0
# 5793   68       0           351               1         0        0
# 5794   68       0           368               2         0        0
# 5795   60       0           397               2         0        0
#
#       loan_amount  loan_tenure_months
# 5000            0                  36
# 5001            0                  36
# 5002            0                  36
# ...

# %%
df.loc[(new_unemp) & (df['age'].between(25, 30)), 'income'] = \
    np.random.randint(10000, 18000, size=df[(new_unemp) & (df['age'].between(25, 30))].shape[0])

df.loc[(new_unemp) & (df['age'].between(31, 35)), 'income'] = \
    np.random.randint(15000, 25000, size=df[(new_unemp) & (df['age'].between(31, 35))].shape[0])

df.loc[(new_unemp) & (df['age'].between(36, 45)), 'income'] = \
    np.random.randint(26000, 28000, size=df[(new_unemp) & (df['age'].between(36, 45))].shape[0])

df.loc[(new_unemp) & (df['age'].between(46, 55)), 'income'] = \
    np.random.randint(28000, 30000, size=df[(new_unemp) & (df['age'].between(46, 55))].shape[0])

df.loc[(new_unemp) & (df['age'].between(56, 59)), 'income'] = \
    np.random.randint(20000, 22000, size=df[(new_unemp) & (df['age'].between(56, 59))].shape[0])

df.loc[(new_unemp) & (df['age'] >= 60), 'income'] = \
    np.random.randint(8000, 15000, size=df[(new_unemp) & (df['age'] >= 60)].shape[0])

print(f"Income assigned to {new_unemp.sum()} unemployed rows!")
# Out:
# Income assigned to 526 unemployed rows!

# %%
df[new_unemp]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5000   32   19523           363               3         0        0
# 5001   70   13433           334               0         0        0
# 5002   53   29201           400               3         0        0
# 5003   26   17421           342               3         0        0
# 5004   52   29260           345               3         0        0
# ...   ...     ...           ...             ...       ...      ...
# 5791   36   27884           353               1         0        0
# 5792   47   28029           304               0         0        0
# 5793   68   11748           351               1         0        0
# 5794   68   10998           368               2         0        0
# 5795   60   13191           397               2         0        0
#
#       loan_amount  loan_tenure_months
# 5000            0                  36
# 5001            0                  36
# 5002            0                  36
# ...

# %%
df.loc[(new_emp) & (df['age'].between(25, 28)), 'income'] = \
    np.random.randint(20000, 35000, size=df[(new_emp) & (df['age'].between(25, 28))].shape[0])

df.loc[(new_emp) & (df['age'].between(29, 30)), 'income'] = \
    np.random.randint(33000, 40000, size=df[(new_emp) & (df['age'].between(29, 30))].shape[0])

df.loc[(new_emp) & (df['age'].between(31, 35)), 'income'] = \
    np.random.randint(45000, 63000, size=df[(new_emp) & (df['age'].between(31, 35))].shape[0])

df.loc[(new_emp) & (df['age'].between(36, 45)), 'income'] = \
    np.random.randint(65000, 85000, size=df[(new_emp) & (df['age'].between(36, 45))].shape[0])

df.loc[(new_emp) & (df['age'].between(46, 55)), 'income'] = \
    np.random.randint(100000, 180000, size=df[(new_emp) & (df['age'].between(46, 55))].shape[0])

df.loc[(new_emp) & (df['age'].between(56, 59)), 'income'] = \
    np.random.randint(100000, 140000, size=df[(new_emp) & (df['age'].between(56, 59))].shape[0])

df.loc[(new_emp) & (df['age'] >= 60), 'income'] = \
    np.random.randint(70000, 100000, size=df[(new_emp) & (df['age'] >= 60)].shape[0])

print(f"Income assigned to {new_emp.sum()} employed rows!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 df.loc[(new_emp) & (df['age'].between(25, 28)), 'income'] = \
# ----> 2     np.random.randint(20000, 35000, size=df[(new_emp) & (df['age'].between(25, 28))].shape[0])
#       4 df.loc[(new_emp) & (df['age'].between(29, 30)), 'income'] = \
#       5     np.random.randint(33000, 40000, size=df[(new_emp) & (df['age'].between(29, 30))].shape[0])
#       7 df.loc[(new_emp) & (df['age'].between(31, 35)), 'income'] = \
#       8     np.random.randint(45000, 63000, size=df[(new_emp) & (df['age'].between(31, 35))].shape[0])
#
# NameError: name 'new_emp' is not defined

# %%
df[new_emp]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5263   70   85959           361               2         1        0
# 5264   68   93605           341               0         1        0
# 5265   43   74005           332               2         1        0
# 5266   37   82908           325               0         1        0
# 5267   45   80298           330               2         1        0
# ...   ...     ...           ...             ...       ...      ...
# 5528   66   96365           392               2         1        0
# 5529   44   80276           400               2         1        0
# 5530   50  173586           399               0         1        0
# 5531   33   56839           341               0         1        0
# 5532   38   70482           333               2         1        0
#
#       loan_amount  loan_tenure_months
# 5263            0                  36
# 5264            0                  36
# 5265            0                  36
# ...

# %%
# Unemployed worst cibil 

new_unemp_loans = (df['employed'] == 0) & (df['loan_amount'] == 0) & (df['credit_score'] < 400)

df.loc[(new_unemp_loans) & (df['age'].between(25, 29)), 'loan_amount'] = \
    df.loc[(new_unemp_loans) & (df['age'].between(25, 29)), 'income'] * np.random.randint(4, 6, size=df[(new_unemp_loans) & (df['age'].between(25, 29))].shape[0])

df.loc[(new_unemp_loans) & (df['age'].between(30, 40)), 'loan_amount'] = \
    df.loc[(new_unemp_loans) & (df['age'].between(30, 40)), 'income'] * np.random.randint(4, 6, size=df[(new_unemp_loans) & (df['age'].between(30, 40))].shape[0])

df.loc[(new_unemp_loans) & (df['age'].between(41, 55)), 'loan_amount'] = \
    df.loc[(new_unemp_loans) & (df['age'].between(41, 55)), 'income'] * np.random.randint(4, 6, size=df[(new_unemp_loans) & (df['age'].between(41, 55))].shape[0])

df.loc[(new_unemp_loans) & (df['age'].between(56, 59)), 'loan_amount'] = \
    df.loc[(new_unemp_loans) & (df['age'].between(56, 59)), 'income'] * np.random.randint(4, 6, size=df[(new_unemp_loans) & (df['age'].between(56, 59))].shape[0])

df.loc[(new_unemp_loans) & (df['age'] >= 60), 'loan_amount'] = \
    df.loc[(new_unemp_loans) & (df['age'] >= 60), 'income'] * np.random.randint(3, 5, size=df[(new_unemp_loans) & (df['age'] >= 60)].shape[0])

df.loc[new_unemp_loans, 'loan_amount'] = df.loc[new_unemp_loans, 'loan_amount'].astype(int)

print(f"Loans assigned to {new_unemp_loans.sum()} unemployed worst credit rows!")
# Out:
# Loans assigned to 516 unemployed worst credit rows!

# %%
df[new_unemp_loans]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5000   32   19523           363               3         0        0
# 5001   70   13433           334               0         0        0
# 5003   26   17421           342               3         0        0
# 5004   52   29260           345               3         0        0
# 5005   49   29392           308               3         0        0
# ...   ...     ...           ...             ...       ...      ...
# 5791   36   27884           353               1         0        0
# 5792   47   28029           304               0         0        0
# 5793   68   11748           351               1         0        0
# 5794   68   10998           368               2         0        0
# 5795   60   13191           397               2         0        0
#
#       loan_amount  loan_tenure_months
# 5000        97615                  36
# 5001        53732                  36
# 5003        69684                  36
# ...

# %%
import pandas as pd
import numpy as np
FILE = "csv-2/copy.csv"
df = pd.read_csv(FILE)

# %%
df.to_csv(FILE, index=False)

# %%
df.loc[
    (df["loan_amount"]==0)
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5002   53   29201           400               3         0        0
# 5024   38   27369           400               2         0        0
# 5044   33   23927           400               1         0        0
# 5079   47   28980           400               0         0        0
# 5100   42   26199           400               1         0        0
# ...   ...     ...           ...             ...       ...      ...
# 5529   44       0           400               2         1        0
# 5531   33       0           341               0         1        0
# 5532   38       0           333               2         1        0
# 5564   58   20684           400               1         0        0
# 5688   49   28240           400               2         0        0
#
#       loan_amount  loan_tenure_months
# 5002            0                  36
# 5024            0                  36
# 5044            0                  36
# ...

# %%
df
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 0      47  105384           616               1         1        0
# 1      40   69517           781               1         1        0
# 2      49   28572           568               2         0        0
# 3      60   71067           654               1         1        1
# 4      39   68930           767               1         1        0
# ...   ...     ...           ...             ...       ...      ...
# 5791   36   27884           353               1         0        0
# 5792   47   28029           304               0         0        0
# 5793   68   11748           351               1         0        0
# 5794   68   10998           368               2         0        0
# 5795   60   13191           397               2         0        0
#
#       loan_amount  loan_tenure_months
# 0          632304                  36
# 1          417102                  36
# 2           83408                  36
# ...

# %%
new_unemp_loans = (df['employed'] == 0) & (df['loan_amount'] == 0) & (df['credit_score'] < 400)

# %%
df[new_unemp_loans]
# Out:
# Empty DataFrame
# Columns: [age, income, credit_score, existing_loans, employed, default, loan_amount, loan_tenure_months]
# Index: []

# %%
new_unemp = (df['employed'] == 0) & (df['income'] == 0)

# %%
df.loc[(new_unemp) & (df['age'].between(25, 30)), 'income'] = \
    np.random.randint(10000, 18000, size=df[(new_unemp) & (df['age'].between(25, 30))].shape[0])

df.loc[(new_unemp) & (df['age'].between(31, 35)), 'income'] = \
    np.random.randint(15000, 25000, size=df[(new_unemp) & (df['age'].between(31, 35))].shape[0])

df.loc[(new_unemp) & (df['age'].between(36, 45)), 'income'] = \
    np.random.randint(26000, 28000, size=df[(new_unemp) & (df['age'].between(36, 45))].shape[0])

df.loc[(new_unemp) & (df['age'].between(46, 55)), 'income'] = \
    np.random.randint(28000, 30000, size=df[(new_unemp) & (df['age'].between(46, 55))].shape[0])

df.loc[(new_unemp) & (df['age'].between(56, 59)), 'income'] = \
    np.random.randint(20000, 22000, size=df[(new_unemp) & (df['age'].between(56, 59))].shape[0])

df.loc[(new_unemp) & (df['age'] >= 60), 'income'] = \
    np.random.randint(8000, 15000, size=df[(new_unemp) & (df['age'] >= 60)].shape[0])

print(f"Income assigned to {new_unemp.sum()} unemployed rows!")
# Out:
# Income assigned to 0 unemployed rows!

# %%
df[new_unemp]
# Out:
# Empty DataFrame
# Columns: [age, income, credit_score, existing_loans, employed, default, loan_amount, loan_tenure_months]
# Index: []

# %%
new_unemp_worst = (df['employed'] == 0) & (df['loan_amount'] == 0) & (df['credit_score'] <= 400)

# %%
df.loc[(new_unemp_worst) & (df['age'].between(25, 29)), 'loan_amount'] = \
    df.loc[(new_unemp_worst) & (df['age'].between(25, 29)), 'income'] * np.random.randint(4, 6, size=df[(new_unemp_worst) & (df['age'].between(25, 29))].shape[0])

df.loc[(new_unemp_worst) & (df['age'].between(30, 40)), 'loan_amount'] = \
    df.loc[(new_unemp_worst) & (df['age'].between(30, 40)), 'income'] * np.random.randint(4, 6, size=df[(new_unemp_worst) & (df['age'].between(30, 40))].shape[0])

df.loc[(new_unemp_worst) & (df['age'].between(41, 55)), 'loan_amount'] = \
    df.loc[(new_unemp_worst) & (df['age'].between(41, 55)), 'income'] * np.random.randint(4, 6, size=df[(new_unemp_worst) & (df['age'].between(41, 55))].shape[0])

df.loc[(new_unemp_worst) & (df['age'].between(56, 59)), 'loan_amount'] = \
    df.loc[(new_unemp_worst) & (df['age'].between(56, 59)), 'income'] * np.random.randint(4, 6, size=df[(new_unemp_worst) & (df['age'].between(56, 59))].shape[0])

df.loc[(new_unemp_worst) & (df['age'] >= 60), 'loan_amount'] = \
    df.loc[(new_unemp_worst) & (df['age'] >= 60), 'income'] * np.random.randint(3, 5, size=df[(new_unemp_worst) & (df['age'] >= 60)].shape[0])

df.loc[new_unemp_worst, 'loan_amount'] = df.loc[new_unemp_worst, 'loan_amount'].astype(int)

print(f"Loans assigned to {new_unemp_worst.sum()} unemployed new rows!")
# Out:
# Loans assigned to 10 unemployed new rows!

# %%
df[new_unemp_worst]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5002   53   29201           400               3         0        0
# 5024   38   27369           400               2         0        0
# 5044   33   23927           400               1         0        0
# 5079   47   28980           400               0         0        0
# 5100   42   26199           400               1         0        0
# 5134   53   28696           400               3         0        0
# 5193   59   21263           400               1         0        0
# 5245   49   29279           400               2         0        0
# 5564   58   20684           400               1         0        0
# 5688   49   28240           400               2         0        0
#
#       loan_amount  loan_tenure_months
# 5002       116804                  36
# 5024       136845                  36
# 5044       119635                  36
# 5079       144900                  36
# ...

# %%
df.loc[
    (df["employed"]==1) &
    (df["income"]==0) &
    (df["credit_score"].between(300, 400))
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5263   70       0           361               2         1        0
# 5264   68       0           341               0         1        0
# 5265   43       0           332               2         1        0
# 5266   37       0           325               0         1        0
# 5267   45       0           330               2         1        0
# ...   ...     ...           ...             ...       ...      ...
# 5528   66       0           392               2         1        0
# 5529   44       0           400               2         1        0
# 5530   50       0           399               0         1        0
# 5531   33       0           341               0         1        0
# 5532   38       0           333               2         1        0
#
#       loan_amount  loan_tenure_months
# 5263            0                  36
# 5264            0                  36
# 5265       500000                  36
# ...

# %%
new_emp_worst = (df['employed'] == 1) & (df['credit_score'].between(300, 400))

# %%
df.loc[(new_emp_worst) & (df['age'].between(25, 28)), 'income'] = \
    np.random.randint(20000, 35000, size=df[(new_emp_worst) & (df['age'].between(25, 28))].shape[0])

df.loc[(new_emp_worst) & (df['age'].between(29, 30)), 'income'] = \
    np.random.randint(33000, 40000, size=df[(new_emp_worst) & (df['age'].between(29, 30))].shape[0])

df.loc[(new_emp_worst) & (df['age'].between(31, 35)), 'income'] = \
    np.random.randint(45000, 63000, size=df[(new_emp_worst) & (df['age'].between(31, 35))].shape[0])

df.loc[(new_emp_worst) & (df['age'].between(36, 45)), 'income'] = \
    np.random.randint(65000, 85000, size=df[(new_emp_worst) & (df['age'].between(36, 45))].shape[0])

df.loc[(new_emp_worst) & (df['age'].between(46, 55)), 'income'] = \
    np.random.randint(100000, 180000, size=df[(new_emp_worst) & (df['age'].between(46, 55))].shape[0])

df.loc[(new_emp_worst) & (df['age'].between(56, 59)), 'income'] = \
    np.random.randint(100000, 140000, size=df[(new_emp_worst) & (df['age'].between(56, 59))].shape[0])

df.loc[(new_emp_worst) & (df['age'] >= 60), 'income'] = \
    np.random.randint(70000, 100000, size=df[(new_emp_worst) & (df['age'] >= 60)].shape[0])

print(f"Income assigned to {new_emp_worst.sum()} employed worst credit rows!")
# Out:
# Income assigned to 272 employed worst credit rows!

# %%
df[new_emp_worst]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 1507   53  169253           399               3         1        1
# 1561   33   45898           375               1         1        0
# 5263   70   70161           361               2         1        0
# 5264   68   83011           341               0         1        0
# 5265   43   67892           332               2         1        0
# ...   ...     ...           ...             ...       ...      ...
# 5528   66   75870           392               2         1        0
# 5529   44   77868           400               2         1        0
# 5530   50  114925           399               0         1        0
# 5531   33   47563           341               0         1        0
# 5532   38   70170           333               2         1        0
#
#       loan_amount  loan_tenure_months
# 1507       545055                  36
# 1561       214932                  36
# 5263            0                  36
# ...

# %%
new_emp_worst_loans = (df['employed'] == 1) & (df['credit_score'].between(300, 400))

# %%
new_emp_worst_loans = (df['employed'] == 1) & (df['loan_amount'] == 0) & (df['credit_score'].between(300, 400))

df.loc[(new_emp_worst_loans) & (df['age'].between(25, 29)), 'loan_amount'] = \
    df.loc[(new_emp_worst_loans) & (df['age'].between(25, 29)), 'income'] * np.random.randint(4, 6, size=df[(new_emp_worst_loans) & (df['age'].between(25, 29))].shape[0])

df.loc[(new_emp_worst_loans) & (df['age'].between(30, 40)), 'loan_amount'] = \
    df.loc[(new_emp_worst_loans) & (df['age'].between(30, 40)), 'income'] * np.random.randint(4, 6, size=df[(new_emp_worst_loans) & (df['age'].between(30, 40))].shape[0])

df.loc[(new_emp_worst_loans) & (df['age'].between(41, 55)), 'loan_amount'] = \
    df.loc[(new_emp_worst_loans) & (df['age'].between(41, 55)), 'income'] * np.random.randint(4, 6, size=df[(new_emp_worst_loans) & (df['age'].between(41, 55))].shape[0])

df.loc[(new_emp_worst_loans) & (df['age'].between(56, 59)), 'loan_amount'] = \
    df.loc[(new_emp_worst_loans) & (df['age'].between(56, 59)), 'income'] * np.random.randint(3, 5, size=df[(new_emp_worst_loans) & (df['age'].between(56, 59))].shape[0])

df.loc[(new_emp_worst_loans) & (df['age'] >= 60), 'loan_amount'] = \
    df.loc[(new_emp_worst_loans) & (df['age'] >= 60), 'income'] * np.random.randint(3, 5, size=df[(new_emp_worst_loans) & (df['age'] >= 60)].shape[0])

df.loc[new_emp_worst_loans, 'loan_amount'] = df.loc[new_emp_worst_loans, 'loan_amount'].astype(int)

print(f"Loans assigned to {new_emp_worst_loans.sum()} employed worst credit rows!")
# Out:
# Loans assigned to 190 employed worst credit rows!

# %%
df[new_emp_worst_loans]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5263   70   70161           361               2         1        0
# 5264   68   83011           341               0         1        0
# 5266   37   75230           325               0         1        0
# 5269   60   70111           340               1         1        0
# 5271   34   61377           356               3         1        0
# ...   ...     ...           ...             ...       ...      ...
# 5527   58  121639           314               0         1        0
# 5528   66   75870           392               2         1        0
# 5529   44   77868           400               2         1        0
# 5531   33   47563           341               0         1        0
# 5532   38   70170           333               2         1        0
#
#       loan_amount  loan_tenure_months
# 5263       280644                  36
# 5264       332044                  36
# 5266       300920                  36
# ...

# %%
df.loc[
    (df["loan_amount"]==500000)
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 5265   43   67892           332               2         1        0
# 5267   45   83161           330               2         1        0
# 5268   51  150202           387               0         1        0
# 5270   55  106863           369               3         1        0
# 5276   53  117922           349               3         1        0
# ...   ...     ...           ...             ...       ...      ...
# 5516   41   74970           390               3         1        0
# 5519   44   65683           305               1         1        0
# 5521   42   84849           387               2         1        0
# 5524   44   76016           359               3         1        0
# 5530   50  114925           399               0         1        0
#
#       loan_amount  loan_tenure_months
# 5265       500000                  36
# 5267       500000                  36
# 5268       500000                  36
# ...

# %%
loan_500k = df['loan_amount'] == 500000

# Income < 100k: normal multiple
df.loc[(loan_500k) & (df['income'] < 100000), 'loan_amount'] = \
    df.loc[(loan_500k) & (df['income'] < 100000), 'income'] * np.random.randint(4, 6, size=df[(loan_500k) & (df['income'] < 100000)].shape[0])

# Income >= 100k: 500k+ with randomness
df.loc[(loan_500k) & (df['income'] >= 100000), 'loan_amount'] = \
    np.random.randint(500000, 800000, size=df[(loan_500k) & (df['income'] >= 100000)].shape[0])

df.loc[loan_500k, 'loan_amount'] = df.loc[loan_500k, 'loan_amount'].astype(int)

print(f"Fixed {loan_500k.sum()} rows with 500k loans!")
# Out:
# Fixed 80 rows with 500k loans!

# %%
df
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 0      47  105384           616               1         1        0
# 1      40   69517           781               1         1        0
# 2      49   28572           568               2         0        0
# 3      60   71067           654               1         1        1
# 4      39   68930           767               1         1        0
# ...   ...     ...           ...             ...       ...      ...
# 5791   36   27884           353               1         0        0
# 5792   47   28029           304               0         0        0
# 5793   68   11748           351               1         0        0
# 5794   68   10998           368               2         0        0
# 5795   60   13191           397               2         0        0
#
#       loan_amount  loan_tenure_months
# 0          632304                  36
# 1          417102                  36
# 2           83408                  36
# ...

# %%
df.loc[
    (df["loan_amount"]>0)
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 0      47  105384           616               1         1        0
# 1      40   69517           781               1         1        0
# 2      49   28572           568               2         0        0
# 3      60   71067           654               1         1        1
# 4      39   68930           767               1         1        0
# ...   ...     ...           ...             ...       ...      ...
# 5791   36   27884           353               1         0        0
# 5792   47   28029           304               0         0        0
# 5793   68   11748           351               1         0        0
# 5794   68   10998           368               2         0        0
# 5795   60   13191           397               2         0        0
#
#       loan_amount  loan_tenure_months
# 0          632304                  36
# 1          417102                  36
# 2           83408                  36
# ...

# %%
df.loc[
    (df["loan_amount"]==0)
]
# Out:
# Empty DataFrame
# Columns: [age, income, credit_score, existing_loans, employed, default, loan_amount, loan_tenure_months]
# Index: []

# %%
df.to_csv("csv-2/copy.csv", index=False)
df.to_csv("csv-2/modified.csv", index=False)
