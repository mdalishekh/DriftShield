# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Date : 2026-04-23

# %%
import pandas as pd
import numpy as np
FILE = "csv-2/copy.csv"
df = pd.read_csv(FILE)

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  employed  default  loan_amount  \
# 0   47       0           616               1         1        0            0
# 1   40       0           781               1         1        0            0
# 2   49       0           568               2         0        0            0
# 3   60       0           654               1         1        1            0
# 4   39       0           767               1         1        0            0
#
#    loan_tenure_months
# 0                  36
# 1                  36
# 2                  36
# 3                  36
# 4                  36

# %%
df.loc[
    (df["existing_loans"]==0) &
    (df["default"]==1)
]
# Out:
# Empty DataFrame
# Columns: [age, income, credit_score, existing_loans, employed, default, loan_amount, loan_tenure_months]
# Index: []

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming aapka dataframe 'df' naam ka hai
plt.figure(figsize=(10, 6))
plt.hist(df['age'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.grid(axis='y', alpha=0.3)
plt.show()

# %%
df[df["loan_amount"]>0]
# Out:
# Empty DataFrame
# Columns: [age, income, credit_score, existing_loans, employed, default, loan_amount, loan_tenure_months]
# Index: []

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  employed  default  loan_amount  \
# 0   47       0           616               1         1        0            0
# 1   40       0           781               1         1        0            0
# 2   49       0           568               2         0        0            0
# 3   60       0           654               1         1        1            0
# 4   39       0           767               1         1        0            0
#
#    loan_tenure_months
# 0                  36
# 1                  36
# 2                  36
# 3                  36
# 4                  36

# %%
unemployed = (df["employed"]==0)
employed = (df["employed"]==1)

# %%
df[unemployed].shape
# Out:
# (718, 8)

# %%
df["age"].max()
# Out:
# 70

# %%
df.loc[
    unemployed &
    (df["age"].between(25, 30))
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 95     25   14191           770               1         0        1
# 193    27   11744           755               2         0        0
# 274    30   14837           750               2         0        1
# 283    27   11708           649               1         0        1
# 325    27   12191           777               1         0        0
# ...   ...     ...           ...             ...       ...      ...
# 4872   27   14096           617               1         0        1
# 4896   25   16605           773               1         0        0
# 4907   28   12044           699               2         0        0
# 4961   29   11272           746               3         0        1
# 4973   25   17576           688               0         0        0
#
#       loan_amount  loan_tenure_months
# 95              0                  36
# 193             0                  36
# 274             0                  36
# ...

# %%
# Income assigning
import numpy as np

# Filter: Unemployed (0) aur Age 25-30
mask = (df["employed"] == 0) & (df["age"].between(25, 30))

# Income assign karo
df.loc[mask, "income"] = df.loc[mask].apply(
    lambda row: np.random.randint(10000, 15000) if np.random.random() < 0.75 
                else np.random.randint(15000, 18000),
    axis=1
)

# %%
# Income assigning

import numpy as np

# Filter: Unemployed (0) aur Age 31-35
mask = (df["employed"] == 0) & (df["age"].between(31, 35))

# Income assign karo (55% → 15k-21k, 45% → 21k-25k)
df.loc[mask, "income"] = df.loc[mask].apply(
    lambda row: np.random.randint(15000, 21000) if np.random.random() < 0.55 
                else np.random.randint(21000, 25000),
    axis=1
)

# %%
# Filter: Unemployed (0) aur Age 31-35
mask = (df["employed"] == 0) & (df["age"].between(31, 35))

df[mask]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 30     34   15798           763               1         0        1
# 83     35   17965           724               0         0        0
# 103    32   16416           817               3         0        0
# 127    35   19492           771               3         0        1
# 240    32   19227           733               4         0        0
# ...   ...     ...           ...             ...       ...      ...
# 4519   31   21455           624               3         0        1
# 4529   35   21985           550               1         0        0
# 4578   35   16701           676               4         0        0
# 4758   34   16045           658               2         0        1
# 4813   32   16604           634               1         0        0
#
#       loan_amount  loan_tenure_months
# 30              0                  36
# 83              0                  36
# 103             0                  36
# ...

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  employed  default  loan_amount  \
# 0   47       0           616               1         1        0            0
# 1   40       0           781               1         1        0            0
# 2   49       0           568               2         0        0            0
# 3   60       0           654               1         1        1            0
# 4   39       0           767               1         1        0            0
#
#    loan_tenure_months
# 0                  36
# 1                  36
# 2                  36
# 3                  36
# 4                  36

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
# Safe point 

df.to_csv(FILE, index=False)

# %%
df = pd.read_csv(FILE)

# %%
df[mask]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 30     34   15798           763               1         0        1
# 83     35   17965           724               0         0        0
# 103    32   16416           817               3         0        0
# 127    35   19492           771               3         0        1
# 240    32   19227           733               4         0        0
# ...   ...     ...           ...             ...       ...      ...
# 4519   31   21455           624               3         0        1
# 4529   35   21985           550               1         0        0
# 4578   35   16701           676               4         0        0
# 4758   34   16045           658               2         0        1
# 4813   32   16604           634               1         0        0
#
#       loan_amount  loan_tenure_months
# 30              0                  36
# 83              0                  36
# 103             0                  36
# ...

# %%
import numpy as np

# Filter: Unemployed (0) aur Age 36-45
mask = (df["employed"] == 0) & (df["age"].between(36, 45))

# Income assign karo (sirf 26k-28k)
df.loc[mask, "income"] = np.random.randint(26000, 28000, size=mask.sum())

# %%
mask = (df["employed"] == 0) & (df["age"].between(36, 45))
df[mask]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 115    45   27814           647               2         0        0
# 116    41   27447           721               1         0        0
# 128    43   26828           805               2         0        0
# 172    41   27886           567               2         0        1
# 190    36   26624           565               4         0        0
# ...   ...     ...           ...             ...       ...      ...
# 4915   44   26161           633               1         0        0
# 4927   44   26167           646               3         0        0
# 4941   39   27471           583               3         0        1
# 4958   41   27814           618               1         0        0
# 4987   42   27657           694               4         0        1
#
#       loan_amount  loan_tenure_months
# 115             0                  36
# 116             0                  36
# 128             0                  36
# ...

# %%
import numpy as np

mask = (df["employed"] == 0) & (df["age"].between(46, 55))

df.loc[mask, "income"] = np.random.randint(28000, 30000, size=mask.sum())

# %%
mask = (df["employed"] == 0) & (df["age"].between(46, 55))
df[mask]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 2      49   28572           568               2         0        0
# 67     54   29050           653               0         0        0
# 75     51   28178           662               0         0        0
# 105    46   29031           471               1         0        1
# 118    55   28857           680               2         0        1
# ...   ...     ...           ...             ...       ...      ...
# 4852   48   28405           679               2         0        1
# 4857   53   28191           707               2         0        0
# 4905   53   29052           685               0         0        0
# 4912   51   29587           831               2         0        1
# 4993   48   29448           723               3         0        1
#
#       loan_amount  loan_tenure_months
# 2               0                  36
# 67              0                  36
# 75              0                  36
# ...

# %%
import numpy as np

mask = (df["employed"] == 0) & (df["age"].between(56, 59))

df.loc[mask, "income"] = np.random.randint(20000, 22000, size=mask.sum())

# %%
mask = (df["employed"] == 0) & (df["age"].between(56, 59))
df[mask]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 65     58   20213           626               3         0        0
# 306    57   20065           732               1         0        0
# 397    58   21758           810               2         0        0
# 924    56   20848           784               3         0        0
# 1166   58   20253           719               1         0        0
# 1181   58   21322           829               1         0        0
# 1509   59   21816           747               0         0        0
# 1601   58   21092           673               1         0        0
# 1676   56   21719           823               1         0        1
# 1951   57   21255           733               2         0        0
# 2964   56   20399           659               2         0        1
# 3049   56   20165           854               5         0        1
# 3203   57   20847           572               2         0        0
# ...

# %%
import numpy as np

mask = (df["employed"] == 0) & (df["age"] >= 60)

df.loc[mask, "income"] = np.random.randint(8000, 15000, size=mask.sum())

# %%
mask = (df["employed"] == 0) & (df["age"] >= 60)
df[mask]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 106    64   13086           738               1         0        0
# 135    60   13841           708               0         0        0
# 209    70   14304           705               1         0        1
# 387    64    9529           536               3         0        1
# 393    63    9360           755               0         0        0
# 494    60    9700           680               0         0        0
# 624    61   10560           714               5         0        1
# 738    61    9773           652               2         0        0
# 880    70   12384           735               3         0        1
# 885    64   10285           729               3         0        0
# 967    63   14154           707               1         0        1
# 996    63    9728           654               2         0        0
# 1154   61   12006           812               3         0        0
# ...
