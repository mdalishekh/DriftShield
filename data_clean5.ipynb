# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
import numpy as np
FILE_PATH = "csv-2/copy.csv"
df = pd.read_csv(FILE_PATH)

# %%
df = pd.read_csv(FILE_PATH)

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  existing_loan_emi  employed  \
# 0   47  105384           616               1                  0         1
# 1   40   69517           781               1                  0         1
# 2   49   28572           568               2                  0         0
# 3   60   71067           654               1                  0         1
# 4   39   68930           767               1                  0         1
#
#    default  loan_amount  loan_tenure_months
# 0        0       632304                  24
# 1        0       417102                  12
# 2        0        83408                  12
# 3        1       284268                  24
# 4        0       482510                  12

# %%
df.to_csv(FILE_PATH, index=False)

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  employed  default  loan_amount  \
# 0   47  105384           616               1         1        0       632304
# 1   40   69517           781               1         1        0       417102
# 2   49   28572           568               2         0        0        83408
# 3   60   71067           654               1         1        1       284268
# 4   39   68930           767               1         1        0       482510
#
#    loan_tenure_months
# 0                  24
# 1                  12
# 2                  12
# 3                  24
# 4                  12

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  employed  default  loan_amount  \
# 0   47  105384           616               1         1        0       632304
# 1   40   69517           781               1         1        0       417102
# 2   49   28572           568               2         0        0        83408
# 3   60   71067           654               1         1        1       284268
# 4   39   68930           767               1         1        0       482510
#
#    loan_tenure_months
# 0                  24
# 1                  12
# 2                  12
# 3                  24
# 4                  12

# %%
df["existing_loan_emi"] = 0

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  employed  default  loan_amount  \
# 0   47  105384           616               1         1        0       632304
# 1   40   69517           781               1         1        0       417102
# 2   49   28572           568               2         0        0        83408
# 3   60   71067           654               1         1        1       284268
# 4   39   68930           767               1         1        0       482510
#
#    loan_tenure_months  existing_loan_emi
# 0                  24                  0
# 1                  12                  0
# 2                  12                  0
# 3                  24                  0
# 4                  12                  0

# %%
df = df[["age", "income", "credit_score", "existing_loans", "existing_loan_emi", "employed",
   "default", "loan_amount", "loan_tenure_months"
   ]]

# %%
df.to_csv(FILE_PATH, index=False)

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  existing_loan_emi  employed  \
# 0   47  105384           616               1                  0         1
# 1   40   69517           781               1                  0         1
# 2   49   28572           568               2                  0         0
# 3   60   71067           654               1                  0         1
# 4   39   68930           767               1                  0         1
#
#    default  loan_amount  loan_tenure_months
# 0        0       632304                  24
# 1        0       417102                  12
# 2        0        83408                  12
# 3        1       284268                  24
# 4        0       482510                  12

# %%
# Adding new columns

df["employement_type"] = None

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  existing_loan_emi  employed  \
# 0   47  105384           616               1                  0         1
# 1   40   69517           781               1                  0         1
# 2   49   28572           568               2                  0         0
# 3   60   71067           654               1                  0         1
# 4   39   68930           767               1                  0         1
#
#    default  loan_amount  loan_tenure_months employement_type
# 0        0       632304                  24             None
# 1        0       417102                  12             None
# 2        0        83408                  12             None
# 3        1       284268                  24             None
# 4        0       482510                  12             None

# %%
df[["emi_to_income_ratio", "loan_to_income_ratio"]] = 0

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  existing_loan_emi  employed  \
# 0   47  105384           616               1                  0         1
# 1   40   69517           781               1                  0         1
# 2   49   28572           568               2                  0         0
# 3   60   71067           654               1                  0         1
# 4   39   68930           767               1                  0         1
#
#    default  loan_amount  loan_tenure_months employement_type  \
# 0        0       632304                  24             None
# 1        0       417102                  12             None
# 2        0        83408                  12             None
# 3        1       284268                  24             None
# 4        0       482510                  12             None
#
#    emi_to_income_ratio  loan_to_income_ratio
# 0                    0                     0
# 1                    0                     0
# ...

# %%
import pandas as pd
import numpy as np
FILE_PATH = "csv-2/copy.csv"
df = pd.read_csv(FILE_PATH)
