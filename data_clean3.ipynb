# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Date :- 2026-04-22

# %%
import pandas as pd
import numpy as np

# %%
FILE_PATH = "csv/copy.csv"

# %%
df = pd.read_csv(FILE_PATH)

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  employed  default  loan_amount  \
# 0   47   18703           616               1         1        0          0.0
# 1   40   16169           781               1         1        0          0.0
# 2   49   14477           568               2         0        0          0.0
# 3   60   14922           654               1         1        1          0.0
# 4   39   15606           767               1         1        0          0.0
#
#    loan_tenure_months
# 0                  36
# 1                  36
# 2                  36
# 3                  36
# 4                  36

# %%
df[df["loan_amount"]==0]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 0      47   18703           616               1         1        0
# 1      40   16169           781               1         1        0
# 2      49   14477           568               2         0        0
# 3      60   14922           654               1         1        1
# 4      39   15606           767               1         1        0
# ...   ...     ...           ...             ...       ...      ...
# 4993   48   19630           723               3         0        1
# 4994   34   19383           839               1         1        0
# 4996   50   18314           768               3         1        0
# 4998   51   17608           638               0         1        0
# 4999   31   18223           674               1         1        0
#
#       loan_amount  loan_tenure_months
# 0             0.0                  36
# 1             0.0                  36
# 2             0.0                  36
# ...

# %%
df.loc[
    (df["age"]>=70) &
    (df["employed"]==1)
].shape
# Out:
# (39, 8)

# %%
unemployed = (df["employed"]==0) & \
(df["loan_amount"]==0)

# %%
df[unemployed]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 2      49   14477           568               2         0        0
# 30     34   17060           763               1         0        1
# 65     58   16334           626               3         0        0
# 83     35   19649           724               0         0        0
# 95     25   12044           770               1         0        1
# ...   ...     ...           ...             ...       ...      ...
# 4958   41   12199           618               1         0        0
# 4961   29   12646           746               3         0        1
# 4973   25   12402           688               0         0        0
# 4987   42   13410           694               4         0        1
# 4993   48   19630           723               3         0        1
#
#       loan_amount  loan_tenure_months
# 2             0.0                  36
# 30            0.0                  36
# 65            0.0                  36
# ...

# %%
unemp_oldage = unemployed & \
(df["age"]>=60)

# %%
df[unemp_oldage].shape
# Out:
# (31, 8)

# %%
df[unemp_oldage]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 393    63   16279           755               0         0        0
# 624    61   12291           714               5         0        1
# 880    70   16940           735               3         0        1
# 885    64   15378           729               3         0        0
# 1154   61   15135           812               3         0        0
# 1157   69   15651           676               3         0        1
# 1466   62   14686           623               3         0        0
# 1541   63   19739           797               3         0        0
# 1910   62   18038           705               4         0        1
# 2164   60   14927           824               1         0        0
# 2411   60   19068           784               3         0        1
# 2506   70   18745           651               3         0        0
# 2544   70   13296           635               3         0        0
# ...

# %%
df.loc[unemp_oldage.index, 'income']
# Out:
# 0       18703
# 1       16169
# 2       14477
# 3       14922
# 4       15606
#         ...
# 4995    15236
# 4996    18314
# 4997    17273
# 4998    17608
# 4999    18223
# Name: income, Length: 5000, dtype: int64

# %%
# # Pension assign karo
# df.loc[unemp_oldage.index, 'income'] = np.random.randint(12000, 20000, size=unemp_oldage.shape[0])

# print(f"Pension assigned to {unemp_oldage.shape[0]} persons")

# %%
df[unemp_oldage].shape
# Out:
# (31, 8)

# %%
unemp_young = unemployed & \
(df["age"]<60)

# %%
df.loc[
    unemp_young &
    (df["income"]<20000)
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 2      49   14477           568               2         0        0
# 30     34   17060           763               1         0        1
# 65     58   16334           626               3         0        0
# 83     35   19649           724               0         0        0
# 95     25   12044           770               1         0        1
# ...   ...     ...           ...             ...       ...      ...
# 4958   41   12199           618               1         0        0
# 4961   29   12646           746               3         0        1
# 4973   25   12402           688               0         0        0
# 4987   42   13410           694               4         0        1
# 4993   48   19630           723               3         0        1
#
#       loan_amount  loan_tenure_months
# 2             0.0                  36
# 30            0.0                  36
# 65            0.0                  36
# ...

# %%
print(df[unemp_young]['credit_score'].describe())
# Out:
# count    485.000000
# mean     713.490722
# std       83.541661
# min      471.000000
# 25%      653.000000
# 50%      718.000000
# 75%      772.000000
# max      900.000000
# Name: credit_score, dtype: float64

# %%
df.to_csv(FILE_PATH, index=False)

# %%
df.loc[(df["loan_amount"]==0)]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 0      47   18703           616               1         1        0
# 1      40   16169           781               1         1        0
# 2      49   14477           568               2         0        0
# 3      60   14922           654               1         1        1
# 4      39   15606           767               1         1        0
# ...   ...     ...           ...             ...       ...      ...
# 4993   48   19630           723               3         0        1
# 4994   34   19383           839               1         1        0
# 4996   50   18314           768               3         1        0
# 4998   51   17608           638               0         1        0
# 4999   31   18223           674               1         1        0
#
#       loan_amount  loan_tenure_months
# 0             0.0                  36
# 1             0.0                  36
# 2             0.0                  36
# ...

# %%
import pandas as pd
import numpy as np
FILE_PATH = "csv/copy.csv"
df = pd.read_csv(FILE_PATH)

# %%
df.head()
# Out:
#    age  income  credit_score  existing_loans  employed  default  loan_amount  \
# 0   47   18703           616               1         1        0          0.0
# 1   40   16169           781               1         1        0          0.0
# 2   49   14477           568               2         0        0          0.0
# 3   60   14922           654               1         1        1          0.0
# 4   39   15606           767               1         1        0          0.0
#
#    loan_tenure_months
# 0                  36
# 1                  36
# 2                  36
# 3                  36
# 4                  36

# %%
df[df["loan_amount"]==0].shape
# Out:
# (3882, 8)

# %%
df[unemp_oldage].shape[0]
# Out:
# 31

# %%
# Minimum 80k-100k guarantee
df.loc[unemp_oldage, 'loan_amount'] = np.round(
    np.random.randint(80000, 100000, size=df[unemp_oldage].shape[0])
)

# df.loc[unemp_oldage.index, 'loan_amount'] = df.loc[unemp_oldage.index, 'loan_amount'].astype(int)

print(f"Loan assigned: {df[unemp_oldage].shape[0]} rows")
# Out:
# Loan assigned: 31 rows

# %%
df.loc[
    (df["loan_amount"]==0)&
    (df["employed"]==0)
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 2      49   14477           568               2         0        0
# 30     34   17060           763               1         0        1
# 65     58   16334           626               3         0        0
# 83     35   19649           724               0         0        0
# 95     25   12044           770               1         0        1
# ...   ...     ...           ...             ...       ...      ...
# 4958   41   12199           618               1         0        0
# 4961   29   12646           746               3         0        1
# 4973   25   12402           688               0         0        0
# 4987   42   13410           694               4         0        1
# 4993   48   19630           723               3         0        1
#
#       loan_amount  loan_tenure_months
# 2             0.0                  36
# 30            0.0                  36
# 65            0.0                  36
# ...

# %%
un= (df["employed"]==0)

# %%
df.loc[
    
    (df["loan_amount"]>0)
].shape
# Out:
# (1149, 8)

# %%
df[unemp_young].shape
# Out:
# (485, 8)

# %%
high_cib = unemp_young & (df["credit_score"]>=700)

# %%
mid_cib = unemp_young & (df["credit_score"].between(550, 699))

# %%
low_cib = unemp_young & (df["credit_score"]<550)

# %%
df[low_cib].shape
# Out:
# (13, 8)

# %%
high_cib.shape
# Out:
# (5000,)

# %%
# High credit
df.loc[high_cib, 'loan_amount'] = df.loc[high_cib, 'income'] * 3 * \
                                         np.round(np.random.uniform(0.9, 1.1, size=df[high_cib].shape[0]))

# %%
# Mid credit
df.loc[mid_cib, 'loan_amount'] = df.loc[mid_cib, 'income'] * 2 * \
                                        np.round(np.random.uniform(0.9, 1.1, size=df[mid_cib].shape[0]))

# %%
# Low credit
df.loc[low_cib, 'loan_amount'] = df.loc[low_cib, 'income'] * 1.5 * \
                                        np.round(np.random.uniform(0.9, 1.1, size=df[low_cib].shape[0]))

# %%
df.loc[unemp_young.index, 'loan_amount'] = df.loc[unemp_young.index, 'loan_amount'].astype(int)

print(f"unemp_young loan assigned!")
# Out:
# unemp_young loan assigned!

# %%
df.loc[
    unemp_young &
    df["loan_amount"]>0
].shape
# Out:
# (485, 8)

# %%
# 60+ unemployed (unemp_oldage)
# high_cib_old = unemp_oldage[unemp_oldage['credit_score'] > 700]
high_cib_old = unemp_oldage & (df['credit_score'] > 700)

mid_cib_old = unemp_oldage & (df['credit_score'].between(550, 700))
low_cib_old = unemp_oldage & (df['credit_score']<550)

# %%
df[low_cib_old].shape
# Out:
# (1, 8)

# %%
# High credit
df.loc[high_cib_old, 'loan_amount'] = np.maximum(
    df.loc[high_cib_old, 'income'] * 5 * np.round(np.random.uniform(0.9, 1.1, size=df[high_cib_old].shape[0])),
    np.random.randint(90000, 100000, size=df[high_cib_old].shape[0])
)

# %%
# Mid credit
df.loc[mid_cib_old, 'loan_amount'] = np.maximum(
    df.loc[mid_cib_old, 'income'] * 4 * np.round(np.random.uniform(0.9, 1.1, size=df[mid_cib_old].shape[0])),
    np.random.randint(70000, 80000, size=df[mid_cib_old].shape[0])
)

# %%
# Low credit
df.loc[low_cib_old, 'loan_amount'] = np.maximum(
    df.loc[low_cib_old, 'income'] * 3 * np.round(np.random.uniform(0.9, 1.1, size=df[low_cib_old].shape[0])),
    np.random.randint(50000, 60000, size=df[low_cib_old].shape[0])
)

# %%
df.loc[unemp_oldage.index, 'loan_amount'] = df.loc[unemp_oldage.index, 'loan_amount'].astype(int)

print("60+ credit-based loan assigned!")

# %%
df.loc[
    unemp_oldage & 
    (df["loan_amount"]>0)
].shape
# Out:
# (0, 8)

# %%
df.loc[
    (df["loan_amount"]==0)
].shape
# Out:
# (3366, 8)

# %%
emp = (df["employed"]==1)

# %%
unemp = (df["employed"]==0)

# %%
old_age = (df["age"]>=60)
young_age = (df["age"]<60)

# %%
high_c = (df["credit_score"]>700)
mid_c  = (df["credit_score"].between(550, 700))
low_c  = (df["credit_score"]<550)

# %%
df[high_c].shape
# Out:
# (2443, 8)

# %%
un_assigned = (df["loan_amount"]==0)
assigned = (df["loan_amount"]>0)

# %%
df.loc[
    assigned &
    emp & old_age & high_c
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 6      60   15257           790               1         1        0
# 71     60   13204           770               1         1        0
# 73     60   13120           789               3         1        0
# 113    70   13211           779               5         1        1
# 125    68   12007           805               1         1        0
# ...   ...     ...           ...             ...       ...      ...
# 4667   61   14903           720               2         1        1
# 4784   70   15840           765               2         1        0
# 4870   70   19475           724               5         1        0
# 4985   61   18109           735               2         1        0
# 4997   70   17273           788               2         1        0
#
#       loan_amount  loan_tenure_months
# 6             0.0                  36
# 71            0.0                  36
# 73            0.0                  36
# ...

# %%
df[assigned & emp & old_age & high_c].shape[0]
# Out:
# 137

# %%
# Assigning loan to Employed Old Aged

# %%
# Old age high credit
df.loc[un_assigned & emp & old_age & high_c, 'loan_amount'] = df.loc[un_assigned & emp & old_age & high_c, 'income'] * 7 * \
                                                 np.round(np.random.uniform(0.9, 1.1, size=df[un_assigned & emp & old_age & high_c].shape[0]))

# %%
# Old age high credit
df.loc[assigned & emp & old_age & high_c, 'loan_amount'] = 0

# %%
df[un_assigned].shape
# Out:
# (3263, 8)

# %%
df.loc[
    un_assigned & emp & old_age &
    (df["income"]<=19999)
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 3      60   14922           654               1         1        1
# 31     64   14993           680               5         1        0
# 156    64   18434           614               2         1        0
# 179    70   14555           674               1         1        0
# 252    67   16444           689               1         1        0
# ...   ...     ...           ...             ...       ...      ...
# 4887   61   15969           602               2         1        0
# 4920   61   14792           675               1         1        0
# 4932   60   14493           700               1         1        0
# 4944   62   14941           581               0         1        0
# 4989   70   16922           698               1         1        0
#
#       loan_amount  loan_tenure_months
# 3             0.0                  36
# 31            0.0                  36
# 156           0.0                  36
# ...

# %%
df.loc[
    (df["income"]>50000)
    
    ]
# Out:
# Empty DataFrame
# Columns: [age, income, credit_score, existing_loans, employed, default, loan_amount, loan_tenure_months]
# Index: []

# %%
df[df["income"]>50000]
# Out:
# Empty DataFrame
# Columns: [age, income, credit_score, existing_loans, employed, default, loan_amount, loan_tenure_months]
# Index: []

# %%
print(df.shape[0])  # Total rows check kar
print(df['loan_amount'].isna().sum())  # Null loans
print(df[df['loan_amount'] == 0].shape[0])  # Zero loans
# Out:
# 5000
# 0
# 3400

# %%
df.loc[
    (df["loan_amount"]>900000)
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 122    58   16414           770               5         1        0
# 141    57   17346           807               3         1        0
# 316    50   16129           818               5         1        0
# 373    53   13757           785               1         1        0
# 388    53   15329           787               2         1        0
# ...   ...     ...           ...             ...       ...      ...
# 4786   50   18822           816               2         1        0
# 4838   58   18458           778               2         1        0
# 4856   52   17910           753               0         1        0
# 4937   56   13729           776               2         1        0
# 4957   54   19265           771               0         1        0
#
#       loan_amount  loan_tenure_months
# 122     1066288.0                  36
# 141     1027824.0                  36
# 316     1200200.0                  36
# ...

# %%
df.to_csv(FILE_PATH, index=False)

# %%
df=pd.read_csv(FILE_PATH)

# %%
df.loc[
    (df["loan_amount"]>900000)
]
# Out:
#       age  income  credit_score  existing_loans  employed  default  \
# 122    58   16414           770               5         1        0
# 141    57   17346           807               3         1        0
# 316    50   16129           818               5         1        0
# 373    53   13757           785               1         1        0
# 388    53   15329           787               2         1        0
# ...   ...     ...           ...             ...       ...      ...
# 4786   50   18822           816               2         1        0
# 4838   58   18458           778               2         1        0
# 4856   52   17910           753               0         1        0
# 4937   56   13729           776               2         1        0
# 4957   54   19265           771               0         1        0
#
#       loan_amount  loan_tenure_months
# 122     1066288.0                  36
# 141     1027824.0                  36
# 316     1200200.0                  36
# ...
